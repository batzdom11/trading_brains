# %% [markdown]
# # Check full reporting dashboard here:
# https://lookerstudio.google.com/s/kIh7VAGL0B8

# %%
# !pip install google-cloud-bigquery pandas db-dtypes
# Out:
# ...
#    ---------------------------------------- 0.0/4.8 MB ? eta -:--:--
#    ---------------------------------------- 4.8/4.8 MB 26.5 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    ---------------------------------------- 3.5/3.5 MB 34.2 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/27.6 MB ? eta -:--:--
#    ------------ --------------------------- 8.4/27.6 MB 40.0 MB/s eta 0:00:01
#    ------------------------- -------------- 17.3/27.6 MB 40.4 MB/s eta 0:00:01
#    ---------------------------------------  27.3/27.6 MB 43.2 MB/s eta 0:00:01
#    ---------------------------------------- 27.6/27.6 MB 38.1 MB/s  0:00:00
# ...
#
#    ----------------------------------------  0/15 [pyasn1]
#    -- -------------------------------------  1/15 [pyarrow]
#    -- -------------------------------------  1/15 [pyarrow]
#    -- -------------------------------------  1/15 [pyarrow]
#    -- -------------------------------------  1/15 [pyarrow]
# ...

# %%
import os
# Remove the old credentials path
if 'GOOGLE_APPLICATION_CREDENTIALS' in os.environ:
    del os.environ['GOOGLE_APPLICATION_CREDENTIALS']

# %%
from google.cloud import bigquery
import pandas as pd
# Initialize client (uses your gcloud credentials)
client = bigquery.Client(project='trading-brains')

# Your query
query = """
SELECT 
  p.timestamp
  , p.last_price_time
  , p.last_price
  , p.pred_60m
  , a.prediction_timestamp
  , a.actual_60m_price
  , a.actual_60m_time
FROM `trading-brains.tft_predictions.tft_predictions_logs` p
JOIN `trading-brains.tft_predictions.tft_actuals` a
  ON p.timestamp = a.prediction_timestamp
ORDER BY p.timestamp DESC
"""

# Run query and get DataFrame
df = client.query(query).to_dataframe()
df
# Out:
# c:\Users\batzi\anaconda3\envs\trading_brains\Lib\site-packages\google\cloud\bigquery\table.py:1994: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#                       timestamp      last_price_time  last_price    pred_60m  \
# 0    2026-04-16T20:00:08.675037  2026-04-16 14:59:00  700.705020  700.922852
# 1    2026-04-16T19:00:17.957503  2026-04-16 14:00:00  700.789980  701.020447
# 2    2026-04-16T18:00:21.969653  2026-04-16 13:00:00  700.780030  701.016724
# 3    2026-04-16T17:00:26.502649  2026-04-16 12:00:00  702.455020  701.270996
# 4    2026-04-16T16:00:27.546062  2026-04-16 11:00:00  700.195680  700.344910
# ..                          ...                  ...         ...         ...
# 142  2026-03-19T18:00:27.786645  2026-03-19 13:00:00  657.169980  657.380798
# 143  2026-03-19T17:00:20.415242  2026-03-19 12:00:00  658.030029  658.106934
# ...
